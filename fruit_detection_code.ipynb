# %%
from ultralytics import YOLO
model = YOLO("yolo11n.pt")
train_result = model.train(data=r"C:\Users\LENOVO\Desktop\fruit object detection\data.yaml" , epochs=5 , imgsz=128 , device="cpu")
# Out:
# New https://pypi.org/project/ultralytics/8.3.28 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.17  Python-3.10.6 torch-2.3.0+cu121 CPU (Intel Core(TM) i3-6006U 2.00GHz)
# ...

# %%
load_build_model = YOLO("runs/detect/train/weights/best.pt")
result = load_build_model("test/images/378_APPLE.jpg")
result[0].show()
# Out:
# image 1/1 C:\Users\LENOVO\Desktop\fruit object detection\test\images\378_APPLE.jpg: 128x128 1 apple, 81.2ms
# Speed: 1.0ms preprocess, 81.2ms inference, 3.2ms postprocess per image at shape (1, 3, 128, 128)

# %%
video_result= load_build_model("fruit_object_video/v1.mp4" , save=True)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/798) C:\Users\LENOVO\Desktop\fruit object detection\fruit_object_video\v1.mp4: 96x128 1 apple, 475.7ms
# video 1/1 (frame 2/798) C:\Users\LENOVO\Desktop\fruit object detection\fruit_object_video\v1.mp4: 96x128 1 apple, 68.3ms
# video 1/1 (frame 3/798) C:\Users\LENOVO\Desktop\fruit object detection\fruit_object_video\v1.mp4: 96x128 (no detections), 75.9ms
# ...
